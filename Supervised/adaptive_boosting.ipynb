# %%
import pandas as pd
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
col_names = ['age','gender','chest pain','rest SBP','cholesterol','fasting blood sugar > 120','rest ECG',
             'max HR','exerc ind ang','ST by exercise','slope peak exc ST','major vessels colored','thal',
             'diameter narrowing']
dataset = pd.read_csv("../Datasets/heart_disease.tab", sep = '\t', header = None, names = col_names)
dataset
# Out:
#      age  gender    chest pain  rest SBP  cholesterol  \
# 0    age  gender    chest pain  rest SBP  cholesterol
# 1      c       d             d         c            c
# 2    NaN     NaN           NaN       NaN          NaN
# 3     63    male   typical ang       145          233
# 4     67    male  asymptomatic       160          286
# ..   ...     ...           ...       ...          ...
# 301   45    male   typical ang       110          264
# 302   68    male  asymptomatic       144          193
# 303   57    male  asymptomatic       130          131
# 304   57  female  atypical ang       130          236
# 305   38    male   non-anginal       138          175
#
#      fasting blood sugar > 120                                       rest ECG  \
# 0    fasting blood sugar > 120                                       rest ECG
# 1                            d  normal left\ vent\ hypertrophy ST-T\ abnormal
# 2                          NaN                                            NaN
# ...

# %%
dataset = dataset.dropna
#dataset
#dataset.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-943d2d17fe81> in <module>
# ----> 1 dataset = dataset.dropna
#       2 #dataset
#       3 #dataset.isnull().sum()
#
# AttributeError: 'function' object has no attribute 'dropna'

# %%
X = dataset.iloc[3:,:-1]
y = dataset.iloc[3:,-1]
X
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-314e65fb0b20> in <module>
# ----> 1 X = dataset.iloc[3:,:-1]
#       2 y = dataset.iloc[3:,-1]
#       3 X
#
# AttributeError: 'function' object has no attribute 'iloc'

# %%
y.head()
# Out:
# 63    0
# 67    1
# 67    1
# 37    0
# 41    0
# Name: thaldiameter narrowing, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder_X = LabelEncoder()
X[:,1] = labelencoder_X.fit_transform(X[:,1])
#X[:,2] = labelencoder_X.fit_transform(X[:,2])
#X[:,6] = labelencoder_X.fit_transform(X[:,6])
#X[:,10] = labelencoder_X.fit_transform(X[:,10])
#X[:,12] = labelencoder_X.fit_transform(X[:,12])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b01004fb1341> in <module>
#       1 labelencoder_X = LabelEncoder()
# ----> 2 X[:,1] = labelencoder_X.fit_transform(X[:,1])
#       3 #X[:,2] = labelencoder_X.fit_transform(X[:,2])
#       4 #X[:,6] = labelencoder_X.fit_transform(X[:,6])
#       5 #X[:,10] = labelencoder_X.fit_transform(X[:,10])
#
# ~/anaconda3/envs/bioinfo/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/anaconda3/envs/bioinfo/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 )
# ...
